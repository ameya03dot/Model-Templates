# %%
import pandas as pd

# %%
dataset = pd.read_csv('Wine.csv')

# %%
X = dataset.iloc[:,:-1].values
y = dataset.iloc[:,-1].values

# %%
from sklearn.model_selection import train_test_split

X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2)

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc= StandardScaler()

X_scaled = sc.fit_transform(X_train)
X_scal = sc.transform(X_test)

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components = 2)

X_scaled = pca.fit_transform(X_scaled)
X_scal = pca.transform(X_scal)

# %%
X_scaled
# Out:
# array([[-1.65021243,  1.45189221],
#        [-2.65720307, -0.64135215],
#        [ 3.07260536, -0.85191179],
#        [ 4.03408566,  0.08548029],
#        [-1.01073042, -0.2316288 ],
#        [ 2.84738092, -0.14813292],
#        [ 2.55223563,  1.58661024],
#        [-0.89130768,  1.54758222],
#        [ 1.09701567, -3.21462157],
#        [ 0.87034975,  2.57253814],
#        [-0.94145076, -1.73421125],
#        [-2.47480151, -1.0095057 ],
#        [ 3.74768522, -0.90034365],
#        [-0.12079672,  2.41759881],
#        [ 0.06452612,  1.87158541],
#        [-0.0411903 ,  1.43927443],
#        [-1.3235716 , -0.7001732 ],
#        [ 0.18526178,  1.20926226],
#        [ 3.16005685, -0.07073083],
#        [ 1.6548727 , -2.04278989],
#        [ 2.53128324, -2.42402968],
#        [-3.04692058, -0.90435523],
#        [-2.48331251, -1.22816153],
#        [-0.36915981,  0.96024356],
#        [-2.57623669, -1.38084221],
#        [-2.94377553, -1.06848341],
#        [ 2.75302686, -0.35578019],
#        [-1.92863876, -1.69930556],
#        [-0.64749407,  3.81451486],
#        [ 3.65842264, -0.57820741],
#        [-1.82707324, -1.66839793],
#        [ 1.50714799,  1.19989664],
#        [ 0.41870844,  2.01786631],
#        [-1.66520806, -0.48188446],
#        [ 2.59966208, -1.81957791],
#        [-0.51885366,  0.02869408],
#        [-2.25370778,  1.59118622],
#        [-2.1566359 , -0.78787333],
#        [ 0.72658058,  2.27263661],
#        [ 3.06818456, -1.7818866 ],
#        [-1.72484646,  0.97527573],
#        [ 3.04729027, -1.54577523],
#        [ 1.84501977, -1.41172919],
#        [ 0.74014153,  1.23985658],
#        [-2.12093916, -1.91498311],
#        [ 0.3527947 ,  2.35464643],
#        [ 0.54797793,  2.46460093],
#        [ 1.08743258,  1.91675133],
#        [-2.17878366, -0.08723223],
#        [-0.97355933, -1.00890629],
#        [ 1.58632662,  0.98958376],
#        [ 2.49444894, -0.15983748],
#        [-0.73197138,  1.46631762],
#        [-1.94754382, -1.08072494],
#        [ 2.5178046 , -0.28646541],
#        [ 2.52936126, -2.38997704],
#        [-1.13856374,  0.25226578],
#        [-1.73960576,  0.3135663 ],
#        [-1.02944333,  1.58704665],
#        [ 0.10147934,  2.25014325],
#        [-2.02576788, -0.51265212],
#        [-4.19450365, -2.00909035],
#        [-1.94115096, -1.17837411],
#        [-1.83265182, -1.85738053],
#        [ 2.3520715 , -1.06632164],
#        [-3.37806771, -1.04336836],
#        [ 4.46948126, -0.23388951],
#        [-2.33500213, -1.07427295],
#        [ 0.64237736,  2.85988579],
#        [-0.96641555,  1.57873254],
#        [-2.02619157, -0.99447848],
#        [-0.32710723, -0.23969737],
#        [ 0.45823788,  2.04213035],
#        [-2.35030334, -1.90171839],
#        [ 0.39369598,  2.46801756],
#        [ 3.34504093, -2.49355297],
#        [ 0.36597144,  2.35063955],
#        [-1.0577426 ,  2.70344604],
#        [ 3.05727702, -0.37091515],
#        [ 2.39827748,  0.75212644],
#        [-2.24149423,  2.14572313],
#        [-2.07704036, -2.39535022],
#        [ 0.57547713,  2.34431004],
#        [-1.85774577, -0.12784411],
#        [ 3.45381234, -1.10290963],
#        [-3.22286789, -1.58369607],
#        [ 1.18781953,  0.59414174],
#        [-2.71751254, -0.51228885],
#        [-0.93789412,  0.79540569],
#        [-2.08986787,  2.05861606],
#        [-2.46150108,  0.09325695],
#        [ 0.4850939 ,  2.82989114],
#        [ 2.73335318, -0.51090408],
#        [ 3.2653874 , -0.38244496],
#        [-0.77306025,  2.47921784],
#        [-2.63143441, -1.43640759],
#        [-3.02604348, -1.64021814],
#        [-1.38905636, -0.48969211],
#        [-3.59902761, -2.69558458],
#        [-0.97379595,  2.27723826],
#        [-1.07078375, -0.03816701],
#        [ 0.87170034,  0.23769256],
#        [-2.52010979, -0.81556008],
#        [-2.91332047, -2.08902141],
#        [ 2.44864035, -2.20876534],
#        [ 3.77028475, -1.48627884],
#        [ 1.90080515,  1.74367283],
#        [ 1.60145669,  1.52387993],
#        [-1.02109735, -1.22811263],
#        [ 4.03628765, -0.51861605],
#        [ 2.67670973, -1.74490061],
#        [-2.20926792, -1.66757971],
#        [ 0.29827613,  2.07371942],
#        [-1.2786491 ,  0.60445396],
#        [-1.8465639 ,  1.34282142],
#        [-0.36366611,  2.39375175],
#        [ 0.53343658,  0.19299476],
#        [ 2.60297605,  0.29557258],
#        [-0.82583533,  2.026401  ],
#        [ 3.7980867 , -0.39972273],
#        [ 0.21528311,  2.95705759],
#        [-0.18576887,  2.67067927],
#        [-1.67625102, -0.5709059 ],
#        [-1.58838043, -0.07754512],
#        [-3.14592963,  0.04383653],
#        [ 2.25699753, -1.88301175],
#        [ 2.37775596, -0.91892212],
#        [ 0.99738372,  3.37765007],
#        [-2.02835347,  0.13304442],
#        [-2.07862018, -1.15077517],
#        [-3.40073177, -2.4434311 ],
#        [-2.60758717, -0.60977478],
#        [-2.59485437, -1.65663351],
#        [ 2.9167934 , -0.47988729],
#        [ 2.26416723, -0.16418127],
#        [ 2.87987782, -2.53204467],
#        [ 2.51651754, -2.13250888],
#        [ 3.07445944, -1.16675928],
#        [-2.08592834,  0.4393902 ],
#        [-1.46643435,  2.15089463],
#        [ 2.8966975 , -1.79617019],
#        [ 2.93778007, -1.21506283]])
